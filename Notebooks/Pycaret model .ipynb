# %%
from pycaret.regression import *
import pandas as pd

# %%
dat = pd.read_excel('validate.xlsx')

# %%
dat.head()
# Out:
#       customer_id  age gender  annual_spend  spending_ratio
# 0  CUS-1005756967   25      F         32561            0.34
# 1  CUS-1005756977   30      M         13672            0.21
# 2  CUS-1005756943   21      M         22315            0.44
# 3  CUS-1005756923   32      M          5002            0.36
# 4  CUS-1005756924   27      F          7154            0.29

# %%
data = pd.read_csv('data/salary.csv')

# %%
data.head()
# Out:
#       customer_id  credit_amount_3m  annual_salary  age gender  annual_spend  \
# 0  CUS-1005756958          12616.11       50464.44   53      F      14611.44
# 1  CUS-1117979751          25050.55      100202.20   21      M      35735.28
# 2  CUS-1140341822          11499.06       45996.24   28      M      22046.16
# 3  CUS-1147642491          22248.07       88992.28   34      F      26931.00
# 4  CUS-1196156254          27326.11      109304.44   34      F      34898.44
#
#    spending_ratio
# 0            0.29
# 1            0.36
# 2            0.48
# 3            0.30
# 4            0.32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       100 non-null    object
#  1   credit_amount_3m  100 non-null    float64
#  2   annual_salary     100 non-null    float64
#  3   age               100 non-null    int64
#  4   gender            100 non-null    object
#  5   annual_spend      100 non-null    float64
#  6   spending_ratio    100 non-null    float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.6+ KB

# %%
data.drop(columns=['credit_amount_3m'], inplace=True)

# %%
mod = setup(data=data, target='annual_salary', session_id=123, ignore_features=['customer_id'], categorical_features=['gender'],
           transformation=True, normalize=True, remove_outliers=True, feature_interaction=True)
# Out:
# <style type="text/css">
# #T_a0408_row27_col1, #T_a0408_row29_col1, #T_a0408_row38_col1, #T_a0408_row42_col1, #T_a0408_row53_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a0408_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0408_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0408_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a0408_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a0408_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0408_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a0408_row1_col1" class="data row1 col1" >annual_salary</td>
#     </tr>
#     <tr>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_9e10b_ th {
#   text-align: left;
# }
# ...

# %%
best
# Out:
# HuberRegressor(alpha=0.0001, epsilon=1.35, fit_intercept=True, max_iter=100,
#                tol=1e-05, warm_start=False)

# %%
save_model(best, 'salary_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['gender'],
#                                        display_types=True,
#                                        features_todrop=['customer_id'],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],
#                                        target='annual_salary',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_nume...
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs',
# ...

# %%
data[data['spending_ratio'] == 1]
